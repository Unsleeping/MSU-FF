# %%
import matplotlib.pyplot as plt
import numpy as np

x = [0, 0.25* .6, .25, .5 + .25*.4, .5 + .25* .8, .75 + .25*.7, 1 + .25*.4, 1.25, 1.25 + .6*.25, 1.5 + 0.25 * .4, 1.75 + .25*1.5, 2 + .25*.5]
y = [7.5, 7.4, 7.4, 7.2, 7, 6, 5, 4, 3, 2, 1, .2]
plt.ylabel('$I, mkA$')  
plt.xlabel('$Vсмещ, V$')
plt.scatter(x, y)
plt.plot(x, y)
grid1 = plt.grid(True)
plt.title('Вольт-амперная характеристика \n транзистора')
plt.show()

# %%
x = np.arange(0.6, 2.2, .1)
y = [.73, .39, .3, .13, .12, .12, .11, .11, .12, .14, .15, .18, .21, .27, .37, .75] # alpha * M_{возб}
y2 = [.3, .32, .19, .13, .12, .12, .11, .11, .12, .14, .15, .18, .2, .27, .3, .35]
plt.ylabel('$aM, mHr$')  
plt.xlabel('$Vсмещ, V$')
plt.plot(x, y, label='$aM_{возб}$')
plt.scatter(x, y)
plt.plot(x, y2, label='$aM_{ср}$')
plt.scatter(x, y2)
grid1 = plt.grid(True)
plt.title('Изучение возбуждение и срыва генерации')
plt.show()

# %%
y = np.arange(0.5, 3., .5)
x = [.15, .19, .26, .37, .68]
plt.ylabel('$V_{0}, V$')  
plt.xlabel('$alpha$')
plt.plot(x, y)
plt.scatter(x, y)
grid1 = plt.grid(True)
plt.title('Зависимость амплитуды генерации от величины обратной связи в случае мягкого')
plt.show()

# %%
x = [.3, .4, .45, .58, .68]
y = [1.5, 2, 2.2, 2.4, 2.5]
x2 = [.1, .2, .3, .4, .5, .6, 0.7, 0.75, 0.79, .85]
y2 = [0, 0, 0, 0, 0, 0, 0, 2.6, 2.6, 2.7]
plt.ylabel('$V_{0}, V$')  
plt.xlabel('$alpha$')
plt.plot(x, y)
plt.scatter(x, y)
plt.plot(x2, y2)
plt.scatter(x2, y2)
grid1 = plt.grid(True)
plt.title('Зависимость амплитуды генерации от величины обратной связи в случае жесткого режима')
plt.show()

# %%
k = 3*1000/50/1.4
print(k)
# Out:
# 42.85714285714286

# %%
x = np.arange(.1, 2.1, .1)
y = [1.6*.5, 1.5, 2.2, 3, 3.5, 4, 4.2, 4.4, 4.6]
y2 = []
y3 = []
y4 = []
for i in range(11):
    y.append(4.8)
# print(y)
# print()
for elem in y:
    y2.append(elem / k * 27)
# print(y2)
# print()
for ind in range(len(y2)):
    y3.append(y2[ind] / x[ind])
# print(y3)
for elem in y3:
    y4.append(elem / 1000)
plt.ylabel('$S_av, A/V$')  
plt.xlabel('$V_0, V$')
# plt.plot(x, y3)
# plt.scatter(x, y3)
plt.plot(x_theor, y_theor)
plt.scatter(x_theor, y_theor)
plt.plot(x, y4)
plt.scatter(x, y4)
grid1 = plt.grid(True)
plt.title('Зависимость средней крутизны от амплитуды колебаний на затворе в случае мягкого режима')
plt.show()
x_theor = np.arange(0.1, 2.2, .1)
y_theor = 5 * 10000 * (10 ** (-12))/(x_theor * 0.03 * 10 ** (-3))

# %%
x = np.arange(.1, 2.1, .1)
y = [.21, .5, .85, 1.3, 1.8, 2.3, 2.8, 3.2, 3.6, 4.2, 4.4, 5.2, 5.4, 5.4]
y2 = []
y4 = []
y3 = []
for i in range(5):
    y.append(5.6)
y.append(5.2)
# print(y)
# print()
for elem in y:
    y2.append(elem / k * 27)
# print(y2)
# print()
for ind in range(len(y2)):
    y3.append(y2[ind] / x[ind])
# print(y3)

for elem in y3:
    y4.append(elem / 1000)
plt.ylabel('$S_av, A/V$')  
plt.xlabel('$V_0, V$')
# plt.plot(x, y3)
# plt.scatter(x, y3)
# plt.plot(x_theor, y_theor)
# plt.scatter(x_theor, y_theor)
plt.plot(x, y4)
plt.scatter(x, y4)
grid1 = plt.grid(True)
plt.title('Зависимость средней крутизны от амплитуды колебаний на затворе в случае жесткого режима')
plt.show()


x_theor = np.arange(0.6, 2.2, .1)
y_theor = 5 * 10000 * (10 ** (-12))/(x_theor * 0.03 * 10 ** (-3))
