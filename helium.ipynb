# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
N1 = [97, 294.8, 533, 794, 1346, 1920, 2505, 3691, 5489]
N2 = [0.00009,0.000273, 0.0049, 0.00074, 0.00124, 0.00177, 0.0023, 0.0034, 0.0051]
p = [.5, 1, 1.5, 2, 3, 4, 5, 7, 10]
# Ne=1e10

# %%
plt.ylabel('$N$')  
plt.xlabel('$p$')
plt.plot(p, N1)
plt.scatter(p, N1)
plt.plot(p, N2)
plt.scatter(p, N2)
grid1 = plt.grid(True)
plt.title('plot')
plt.show()

# %%
# 10e11-10e12
N1 = [549, 1153, 1759, 2365, 2972, 4185, 6006.5]
N2 = [0.005, 0.0108, 0.016, 0.02195, 0.0276, 0.038, 0.0557]
p = [1, 2, 3, 4, 5, 7, 10]
# Ne=1e11

# %%
plt.ylabel('$N$')  
plt.xlabel('$p$')
plt.plot(p, N1)
plt.scatter(p, N1)
plt.plot(p, N2)
plt.scatter(p, N2)
grid1 = plt.grid(True)
plt.title('plot')
plt.show()

# %%
N1 = [601, 1208, 1816, 2423, 3030, 4245, 6067]
N2 = [0.057, 0.12, 0.175, 0.233, 0.292, 0.4089, 0.584]
p = [1, 2, 3, 4, 5, 7, 10]
# Ne=1e12

# %%
plt.ylabel('$N$')  
plt.xlabel('$p$')
plt.plot(p, N1)
plt.scatter(p, N1)
plt.plot(p, N2)
plt.scatter(p, N2)
grid1 = plt.grid(True)
plt.title('plot')
plt.show()

# %%
N1 = [610, 1220, 1830, 2441, 3052, 4273, 6104]
N2 = [0.779, 1.56, 2.34, 3.12, 3.9, 5.46, 7.8]
p = [1, 2, 3, 4, 5, 7, 10]
# Ne=1e13

# %%
plt.ylabel('$N$')  
plt.xlabel('$p$')
plt.plot(p, N1)
plt.scatter(p, N1)
plt.plot(p, N2)
plt.scatter(p, N2)
grid1 = plt.grid(True)
plt.title('plot')
plt.show()

# %%
dN = [2.2862*10**5, 1.8258*10**5, 1.6552*10**5, 1.5196*10**5, 98374, 94031, 91105, 90602, 92072, 90488, 78088, 75839, 74691, 74337, 75411, 74811, 74861, 74761, 70013, 69315, 67979, 68777, 68861, 68635]
E = [19.82, 20.61, 20.96, 21.22, 22.78, 22.92, 23.09, 23.07, 23.01, 23.07, 23.59, 23.67, 23.74, 23.74, 23.71, 23.74, 23.74, 23.74, 23.97, 24.01, 24.04, 24.04, 24.03, 24.04]
lvl = np.arange(1, 25)
y = []
for x in range(0, 24):
    y.append(64782117.73142098*np.exp(-E[x]/3.51))
    
N0 = dN[0]/np.exp(-E[0]/3.51)
print(N0)
# Out:
# 64782117.73142098

# %%
plt.ylabel('$dN$')  
plt.xlabel('$E, V$')
plt.plot(E, dN)
plt.scatter(E, dN)
plt.plot(E, y)
plt.scatter(E, y)
grid1 = plt.grid(True)
plt.title('plot')
plt.show()

# %%
plt.ylabel('$dN$')  
plt.xlabel('$E, V$')
plt.plot(lvl, dN)
plt.scatter(lvl, dN)
grid1 = plt.grid(True)
plt.title('plot')
plt.show()
